-- %%
CREATE CATALOG IF NOT EXISTS dbx_joshdevph_dev; -- Development catalog 
CREATE CATALOG IF NOT EXISTS dbx_joshdevph_prd; -- Production catalog

-- Create volume and schema for development catalog
CREATE SCHEMA IF NOT EXISTS dbx_joshdevph_dev.raw; -- landing stage from volumes
CREATE SCHEMA IF NOT EXISTS dbx_joshdevph_dev.processed; -- processed data from raw
CREATE SCHEMA IF NOT EXISTS dbx_joshdevph_dev.features; -- features for ML models
CREATE SCHEMA IF NOT EXISTS dbx_joshdevph_dev.models; -- fitted ML models metadata
-- CREATE SCHEMA IF NOT EXISTS dbx_joshdevph_dev.model_metrics; -- model performance metrics 
CREATE VOLUME IF NOT EXISTS dbx_joshdevph_dev.raw.vlm; -- volume to store raw files 
CREATE VOLUME IF NOT EXISTS dbx_joshdevph_dev.models.crypto_forecaster; -- volume to store ML models 

-- Create volume and schema for production catalog
CREATE SCHEMA IF NOT EXISTS dbx_joshdevph_prd.raw; -- landing stage from volumes
CREATE SCHEMA IF NOT EXISTS dbx_joshdevph_prd.processed; -- processed data from raw
CREATE SCHEMA IF NOT EXISTS dbx_joshdevph_prd.features; -- features for ML models
CREATE SCHEMA IF NOT EXISTS dbx_joshdevph_prd.models; -- fitted ML models metadata
-- CREATE SCHEMA IF NOT EXISTS dbx_joshdevph_prd.model_metrics; -- model performance metrics
CREATE VOLUME IF NOT EXISTS dbx_joshdevph_prd.raw.vlm; -- volume to store raw files  
CREATE VOLUME IF NOT EXISTS dbx_joshdevph_prd.models.crypto_forecaster; -- volume to store ML models
